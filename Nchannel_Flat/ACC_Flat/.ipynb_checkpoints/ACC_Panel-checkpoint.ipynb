# %% [markdown]
# # <center> ACC_base_script </center>

# %% [markdown]
# Simple Pic of ACC in model

# %%
# Load Modules
import netCDF4
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/noc/users/hb1g13/Python/python_functions/')
import useful as hb
from HB_Plot import nf, fmt
# %matplotlib inline

# %%
Year = 'TAV.nc'
# tau=['3','10','30','100','300','1000','3000','10000','Closed']
tau = ['3', '300', '3000', 'Closed']
Figletter = ['a) ','b) ','c) ','d) ']
x = '/noc/msm/scratch/students/hb1g13/Mobilis'

# Now Make file structure
check = 0
runs = []
for i in range(len(tau)):
    flist = x+'/'+str(tau[i])+'daynokpp/'+Year
    if not os.path.exists(flist):
        print ' WARNING: '+flist+' does not exist! (skipping this tau...)'
        check += 0
    else:
        check += 1
        runs.append(i) 
gridfilepath = x+'/'+str(tau[0])+'daynokpp/'
file2 = netCDF4.Dataset(gridfilepath+'grid.nc', 'r')
Zp = file2.variables['Zp1'][:]
Z = file2.variables['Z'][:]
Y = file2.variables['Yp1'][:]
Yc = file2.variables['Y'][:]
X=file2.variables['Xp1']
Xp=X[:]
Zmatrix = np.zeros((len(Z), len(Y)))
Zmatrix[:, :] = 1
dx = Y[1]-Y[0]  # Find Resolution
dz = Zp[0:len(Zp)-1]-Zp[1:len(Zp)]
Zmatrix = np.apply_along_axis(np.multiply, 0, Zmatrix, dz)
Runs=np.array(runs)
# Out:
#  WARNING: /noc/msm/scratch/students/hb1g13/Mobilis/300daynokpp/TAV.nc does not exist! (skipping this tau...)
#  WARNING: /noc/msm/scratch/students/hb1g13/Mobilis/3000daynokpp/TAV.nc does not exist! (skipping this tau...)

# %% [markdown]
# Transport given by:
# \begin{equation}
# T=\iint u \mathrm{d}z\mathrm{d}y
# \end{equation}

# %%
fig = plt.figure(figsize=(16.5, 16.5))
Psi_levs = np.arange(0, 800, 50)
Psi_ticks =np.arange(0, 800, 100)
for i in range(len(Runs)):
    filename = x+'/'+str(tau[Runs[i]])+'daynokpp/'+Year
    file2read = netCDF4.Dataset(filename, 'r')
    U = file2read.variables["UVEL"][:]
    Temp = file2read.variables['THETA'][:]
    Tav = np.mean(Temp, axis=0)
    Tavlat = np.mean(Tav, axis=2)
    Utave = np.mean(U, axis=0)
    Uzone = np.nansum(Utave*dx, axis=2)
    # Got rid of for loop here (much quicker!!)
    psi2 = np.apply_along_axis(np.multiply, 0, Uzone, dz)
    psi = np.cumsum(psi2[::-1, :], axis=0)[::-1,:]
    npad = ((0, 1), (0, 0))
    # Pad with zeros at bottom
    psi = np.pad(psi, pad_width=npad, mode='constant',
                 constant_values=0)
    y = Y/1000
    Psi1 = psi/10**6  # Convert to Sv
    Psi = hb.regridz(hb.regridy(Psi1))
    ax = fig.add_subplot(2, 2, i+1)
    p = ax.contourf(Yc/1000, Zp/1000, Psi1, Psi_levs,
                    cmap=plt.cm.YlOrRd)
    Q2_levs = (np.arange(-1, 8, 1))
    q = ax.contour(Yc/1000, Z/1000,
                   Tavlat, Q2_levs, colors='k', linewidths=2)
    q.levels = [nf(val) for val in q.levels]
    plt.clabel(q, q.levels[::2], inline=1, fmt=fmt, fontsize=25)
    ax.tick_params(axis='both', which='major', labelsize=30)
    ax.set_title(str(Figletter[Runs[i]])+str(tau[Runs[i]])+' day', fontsize=30)
    if str(tau[Runs[i]]) == 'Closed':
        ax.set_title(str(Figletter[Runs[i]])+str(tau[Runs[i]]), fontsize=30)
    ax.set_xlabel('Distance (km)', fontsize=30)
    ax.set_ylabel('Depth (km)', fontsize=30)
plt.tight_layout()
cax = fig.add_axes([1, 0.1, 0.03, 0.8])
cbar = fig.colorbar(p, cax=cax, ticks=Psi_ticks)
cbar.ax.set_ylabel('$\Psi$ (Sv)', fontsize=30)
cbar.ax.tick_params(labelsize=30)
